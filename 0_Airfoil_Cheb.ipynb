# %% [markdown]
# ## Imports

# %%
import gc
import numpy as np
import matplotlib.pyplot as plt
import torch
from warnings import filterwarnings
import pickle
import os

import torch_geometric
import torch
from torch_geometric.loader import DataLoader

from src.utils.commons import get_config, get_device, set_seed
from src.model.gae import GAE
from src.training.train_cf import train
from src.data.loader import GraphDataset
from src.utils.commons import get_config
from src.utils.plot import Plot
# Out:
# ---------------------------------------------------------------------------
# KeyboardInterrupt                         Traceback (most recent call last)
# Cell In[1], line 4
#       2 import numpy as np
#       3 import matplotlib.pyplot as plt
# ----> 4 import torch
#       5 from warnings import filterwarnings
#       6 import pickle
#
# File c:\Users\lab_aeroComp\anaconda3\envs\arvi-env\Lib\site-packages\torch\__init__.py:1850
#    1846 import torch._library
#    1848 # quantization depends on torch.fx
#    1849 # Import quantization
# -> 1850 from torch import quantization as quantization
#    1852 # Import the quasi random sampler
#    1853 from torch import quasirandom as quasirandom
#
# File c:\Users\lab_aeroComp\anaconda3\envs\arvi-env\Lib\site-packages\torch\quantization\__init__.py:2
#       1 # mypy: allow-untyped-defs
# ----> 2 from .quantize import *  # noqa: F403
#       3 from .observer import *  # noqa: F403
#       4 from .qconfig import *  # noqa: F403
#
# File c:\Users\lab_aeroComp\anaconda3\envs\arvi-env\Lib\site-packages\torch\quantization\quantize.py:10
#       1 # flake8: noqa: F401
#       2 r"""
#       3 This file is in the process of migration to `torch/ao/quantization`, and
#       4 is kept here for compatibility while the migration process is ongoing.
#    (...)      7 here.
#       8 """
# ---> 10 from torch.ao.quantization.quantize import (
#      11     _add_observer_,
#      12     _convert,
#      13     _get_observer_dict,
#      14     _get_unique_devices_,
#      15     _is_activation_post_process,
#      16     _observer_forward_hook,
#      17     _propagate_qconfig_helper,
#      18     _register_activation_post_process_hook,
#      19     _remove_activation_post_process,
#      20     _remove_qconfig,
#      21     add_quant_dequant,
#      22     convert,
#      23     prepare,
#      24     prepare_qat,
#      25     propagate_qconfig_,
#      26     quantize,
#      27     quantize_dynamic,
#      28     quantize_qat,
#      29     swap_module,
#      30 )
#
# File c:\Users\lab_aeroComp\anaconda3\envs\arvi-env\Lib\site-packages\torch\ao\quantization\__init__.py:4
#       1 # mypy: allow-untyped-defs
#       2 # flake8: noqa: F403
# ----> 4 from .fake_quantize import *  # noqa: F403
#       5 from .fuse_modules import fuse_modules  # noqa: F403
#       6 from .fuse_modules import fuse_modules_qat  # noqa: F403
#
# File c:\Users\lab_aeroComp\anaconda3\envs\arvi-env\Lib\site-packages\torch\ao\quantization\fake_quantize.py:6
#       4 import torch
#       5 from torch.nn import Module
# ----> 6 from torch.ao.quantization.observer import (
#       7     MovingAverageMinMaxObserver,
#       8     HistogramObserver,
#       9     MovingAveragePerChannelMinMaxObserver,
#      10     FixedQParamsObserver,
#      11     default_fixed_qparams_range_0to1_observer,
#      12     default_fixed_qparams_range_neg1to1_observer,
#      13     _with_args,
#      14 )
#      15 import re
#      16 from abc import ABC, abstractmethod
#
# File c:\Users\lab_aeroComp\anaconda3\envs\arvi-env\Lib\site-packages\torch\ao\quantization\observer.py:16
#      14 import torch
#      15 import torch.nn as nn
# ---> 16 from torch.ao.quantization.utils import (
#      17     check_min_max_valid, calculate_qmin_qmax, is_per_tensor, is_per_channel, validate_qmin_qmax)
#      19 __all__ = [
#      20     "default_affine_fixed_qparams_observer",
#      21     "default_debug_observer",
#    (...)     49     "UniformQuantizationObserverBase",
#      50 ]
#      53 class _PartialWrapper:
#
# File c:\Users\lab_aeroComp\anaconda3\envs\arvi-env\Lib\site-packages\torch\ao\quantization\utils.py:13
#      11 import torch
#      12 from torch.ao.quantization.quant_type import QuantType
# ---> 13 from torch.fx import Node
#      14 from torch.nn.utils.parametrize import is_parametrized
#      16 NodePattern = Union[Tuple[Node, Node], Tuple[Node, Tuple[Node, Node]], Any]
#
# File c:\Users\lab_aeroComp\anaconda3\envs\arvi-env\Lib\site-packages\torch\fx\__init__.py:83
#       1 r'''
#       2 FX is a toolkit for developers to use to transform ``nn.Module``
#       3 instances. FX consists of three main components: a **symbolic tracer,**
#    (...)     80 repository.
#      81 '''
# ---> 83 from .graph_module import GraphModule
#      84 from ._symbolic_trace import symbolic_trace, Tracer, wrap, PH, ProxyableClassMeta
#      85 from .graph import Graph, CodeGen
#
# File c:\Users\lab_aeroComp\anaconda3\envs\arvi-env\Lib\site-packages\torch\fx\graph_module.py:20
#      17 from torch.package import Importer, PackageExporter, PackageImporter, sys_importer
#      19 from ._compatibility import compatibility
# ---> 20 from .graph import _custom_builtins, _is_from_torch, _PyTreeCodeGen, Graph, PythonCode
#      22 __all__ = [
#      23     "reduce_graph_module",
#      24     "reduce_package_graph_module",
#      25     "reduce_deploy_graph_module",
#      26     "GraphModule",
#      27 ]
#      29 _USER_PRESERVED_ATTRIBUTES_KEY = "_user_preserved_attributes"
#
# File c:\Users\lab_aeroComp\anaconda3\envs\arvi-env\Lib\site-packages\torch\fx\graph.py:5
#       3 from .node import Node, Argument, Target, map_arg, _type_repr, _get_qualified_name
#       4 import torch.utils._pytree as pytree
# ----> 5 from . import _pytree as fx_pytree
#       6 from ._compatibility import compatibility
#       8 import os
#
# File c:\Users\lab_aeroComp\anaconda3\envs\arvi-env\Lib\site-packages\torch\fx\_pytree.py:5
#       2 from collections import namedtuple
#       3 from typing import Any, Callable, Dict, List, NamedTuple, Optional, Tuple, Type
# ----> 5 import torch.return_types
#       7 from torch.utils._pytree import PyTree, TreeSpec
#       9 FlattenFuncSpec = Callable[[PyTree, TreeSpec], List]
#
# File c:\Users\lab_aeroComp\anaconda3\envs\arvi-env\Lib\site-packages\torch\return_types.py:48
#      42 # Today everything in torch.return_types is a structseq, aka a "namedtuple"-like
#      43 # thing defined by the Python C-API. We're going to need to modify this when that
#      44 # is no longer the case.
#      45 # NB: I don't know how to check that something is a "structseq" so we do a fuzzy
#      46 # check for tuple
#      47 if inspect.isclass(_attr) and issubclass(_attr, tuple):
# ---> 48     pytree_register_structseq(_attr)
#
# File c:\Users\lab_aeroComp\anaconda3\envs\arvi-env\Lib\site-packages\torch\return_types.py:24, in pytree_register_structseq(cls)
#      21 def structseq_unflatten(values, context):
#      22     return cls(values)
# ---> 24 register_pytree_node(
#      25     cls,
#      26     structseq_flatten,
#      27     structseq_unflatten,
#      28     flatten_with_keys_fn=structseq_flatten_with_keys,
#      29 )
#
# File c:\Users\lab_aeroComp\anaconda3\envs\arvi-env\Lib\site-packages\torch\utils\_pytree.py:213, in register_pytree_node(cls, flatten_fn, unflatten_fn, serialized_type_name, to_dumpable_context, from_dumpable_context, flatten_with_keys_fn)
#     202 _private_register_pytree_node(
#     203     cls,
#     204     flatten_fn,
#    (...)    209     flatten_with_keys_fn=flatten_with_keys_fn,
#     210 )
#     212 try:
# --> 213     from . import _cxx_pytree as cxx
#     214 except ImportError:
#     215     pass
#
# File <frozen importlib._bootstrap>:1176, in _find_and_load(name, import_)
#
# File <frozen importlib._bootstrap>:1138, in _find_and_load_unlocked(name, import_)
#
# File <frozen importlib._bootstrap>:1078, in _find_spec(name, path, target)
#
# File <frozen importlib._bootstrap_external>:1507, in find_spec(cls, fullname, path, target)
#
# File <frozen importlib._bootstrap_external>:1479, in _get_spec(cls, fullname, path, target)
#
# File <frozen importlib._bootstrap_external>:1648, in find_spec(self, fullname, target)
#
# File <frozen importlib._bootstrap_external>:161, in _path_isfile(path)
#
# File <frozen importlib._bootstrap_external>:153, in _path_is_mode_type(path, mode)
#
# File <frozen importlib._bootstrap_external>:147, in _path_stat(path)
#
# KeyboardInterrupt:

# %% [markdown]
# # Inputs

# %%
config_path = 'configs/final/CF_NACA0012Cheb.yaml'
is_train = True

# %% [markdown]
# # Initialization

# %% [markdown]
# ## Dataset

# %%
filterwarnings('ignore')
torch.cuda.empty_cache()
gc.collect()

config = get_config(config_path)
set_seed(config['config']['seed'])

train_dataset = GraphDataset(config = config['config'], split = 'train')
val_dataset = GraphDataset(config = config['config'], split = 'val')
device = get_device()
    
surface_mask = train_dataset.surface_mask

# %%
train_params_list = np.array([[int(keys.split('_')[1]), int(keys.split('_')[3])] for keys in train_dataset.file_keys]).reshape(-1, 2)
test_params_list = np.array([[int(keys.split('_')[1]), int(keys.split('_')[3])] for keys in val_dataset.file_keys]).reshape(-1, 2)

plt.figure(figsize=(10, 6))
# plt.grid(True)
plt.xlabel('Re')
plt.ylabel('AoA')
plt.title('Parameter Space')
plt.scatter(train_params_list[:, 0], train_params_list[:, 1], c='blue', s=30, label='Train')
plt.scatter(test_params_list[:, 0], test_params_list[:, 1], c='red', s=30, label='Test')
plt.legend()
plt.show()

# %% [markdown]
# ## Model

# %%
model_name = config['training']['model_name']
num_epochs = config['training']['epochs']
model_path = f"artifacts/surface/{model_name}/{model_name}_best_model_{num_epochs}.pth"

linear_ae_input_size = train_dataset[0].x.shape[0] * config["model"]['encoder']['convolution_layers']['hidden_channels'][-1]
model = GAE(config = config, ae_input_size = linear_ae_input_size).to(device)

if not is_train:
    from src.utils.commons import load_model
    model = load_model(model_path, config=config, ae_input_ize=train_dataset[0].x.shape[0] * config["model"]['encoder']['convolution_layers']['hidden_channels'][-1])

model = model.to(device)

# %% [markdown]
# # Training

# %%
train_loader = DataLoader(dataset=train_dataset, 
                          batch_size=1, 
                          shuffle=False,
                          num_workers=config['training']['num_workers'])

val_loader = DataLoader(dataset=val_dataset, 
                        batch_size=1, 
                        shuffle=False,
                        num_workers=config['training']['num_workers'])

if is_train:
    history = train(model = model, 
                    device = device, 
                    surface_mask = surface_mask,
                    lambda_surface=1,
                    train_loader = train_loader, 
                    is_val = True,
                    val_loader = val_loader, 
                    start_up_epoch=20,
                    save_best_model=True,
                    save_history=True,
                    config = config['training'])

    train_history, val_history = history
    from src.utils.commons import save_config
    save_config(config, task='airfoil')
# Out:
#   1%|          | 7/1000 [01:08<2:41:57,  9.79s/it, train_loss=0.159185, map_loss=0.000162, reconstruction_loss=0.159023, val_loss=0.225777, val_reconstruction_loss=0.225638, val_map_loss=0.000139]
# ---------------------------------------------------------------------------
# KeyboardInterrupt                         Traceback (most recent call last)
# Cell In[6], line 12
#       6 val_loader = DataLoader(dataset=val_dataset,
#       7                         batch_size=1,
#       8                         shuffle=False,
#       9                         num_workers=config['training']['num_workers'])
#      11 if is_train:
# ---> 12     history = train(model = model,
#      13                     device = device,
#      14                     surface_mask = surface_mask,
#      15                     lambda_surface=1,
#      16                     train_loader = train_loader,
#      17                     is_val = True,
#      18                     val_loader = val_loader,
#      19                     start_up_epoch=20,
#      20                     save_best_model=True,
#      21                     save_history=True,
#      22                     config = config['training'])
#      24     train_history, val_history = history
#      25     from src.utils.commons import save_config
#
# File e:\13621034 Muhammad Arviano Yuono\STABLE\GAE-ROM\src\training\train_cf.py:138, in train(model, device, surface_mask, train_loader, lambda_surface, is_val, val_loader, is_tqdm, single_batch, save_best_model, save_history, start_up_epoch, config)
#     134 # Add gradient clipping
#     135 # torch.nn.utils.clip_grad_norm_(model.parameters(), max_norm=1.0)
#     137 if is_val:
# --> 138     total_loss_val, reconstruction_loss_val, map_loss_val = val(model, device, surface_mask, lambda_surface, val_loader, config['lambda_map'])
#     140     val_history['val_loss'].append(total_loss_val)
#     141     val_history['reconstruction_loss'].append(reconstruction_loss_val)
#
# File e:\13621034 Muhammad Arviano Yuono\STABLE\GAE-ROM\src\training\val_cf.py:39, in val(model, device, surface_mask, lambda_surface, val_loader, lambda_map)
#      37         out, latent_var, est_latent_var = model(val_batch, current_params)
#      38 else:
# ---> 39     out, latent_var, est_latent_var = model(val_batch, current_params)
#      41 start_ind += val_batch.batch_size
#      43 # Calculate reconstruction loss
#
# File c:\Users\lab_aeroComp\anaconda3\envs\arvi-env\Lib\site-packages\torch\nn\modules\module.py:1553, in Module._wrapped_call_impl(self, *args, **kwargs)
#    1551     return self._compiled_call_impl(*args, **kwargs)  # type: ignore[misc]
#    1552 else:
# -> 1553     return self._call_impl(*args, **kwargs)
#
# File c:\Users\lab_aeroComp\anaconda3\envs\arvi-env\Lib\site-packages\torch\nn\modules\module.py:1562, in Module._call_impl(self, *args, **kwargs)
#    1557 # If we don't have any hooks, we want to skip the rest of the logic in
#    1558 # this function, and just call forward.
#    1559 if not (self._backward_hooks or self._backward_pre_hooks or self._forward_hooks or self._forward_pre_hooks
#    1560         or _global_backward_pre_hooks or _global_backward_hooks
#    1561         or _global_forward_hooks or _global_forward_pre_hooks):
# -> 1562     return forward_call(*args, **kwargs)
#    1564 try:
#    1565     result = None
#
# File e:\13621034 Muhammad Arviano Yuono\STABLE\GAE-ROM\src\model\gae.py:66, in GAE.forward(self, data, params, is_verbose)
#      63 else:
#      64     latent_variables, estimated_latent_variables, decoded_reshaped_x = None, None, encoded_x
# ---> 66 estimated_x = self.graph_decoder(data, decoded_reshaped_x, is_verbose=is_verbose)
#      68 # -- Global skip connection --
#      69 # if self.is_skip_connection:
#      70 #     if self.skip_proj is None:
#    (...)     74 #     assert projected_skip.shape == data.x.shape
#      75 #     data.x = data.x + 0.1 * projected_skip
#      77 return estimated_x, latent_variables, estimated_latent_variables
#
# File c:\Users\lab_aeroComp\anaconda3\envs\arvi-env\Lib\site-packages\torch\nn\modules\module.py:1553, in Module._wrapped_call_impl(self, *args, **kwargs)
#    1551     return self._compiled_call_impl(*args, **kwargs)  # type: ignore[misc]
#    1552 else:
# -> 1553     return self._call_impl(*args, **kwargs)
#
# File c:\Users\lab_aeroComp\anaconda3\envs\arvi-env\Lib\site-packages\torch\nn\modules\module.py:1562, in Module._call_impl(self, *args, **kwargs)
#    1557 # If we don't have any hooks, we want to skip the rest of the logic in
#    1558 # this function, and just call forward.
#    1559 if not (self._backward_hooks or self._backward_pre_hooks or self._forward_hooks or self._forward_pre_hooks
#    1560         or _global_backward_pre_hooks or _global_backward_hooks
#    1561         or _global_forward_hooks or _global_forward_pre_hooks):
# -> 1562     return forward_call(*args, **kwargs)
#    1564 try:
#    1565     result = None
#
# File e:\13621034 Muhammad Arviano Yuono\STABLE\GAE-ROM\src\model\graph_decoder.py:23, in GraphDecoder.forward(self, data, decoded_reshaped_x, is_verbose)
#      21 for i, (conv, norm) in enumerate(zip(self.convolution_layers.convs, self.convolution_layers.batch_norms)):
#      22     if self.convolution_layers.config['type'] in ['GMM', 'Cheb', 'GCN']:
# ---> 23         x = conv(x = x, edge_index = data.edge_index, edge_weight = data.edge_weight)
#      24     elif self.convolution_layers.config['type'] in ['GAT', "PNA"]:
#      25         x = conv(x = x, edge_index = data.edge_index, edge_attr = data.edge_attr)
#
# File c:\Users\lab_aeroComp\anaconda3\envs\arvi-env\Lib\site-packages\torch\nn\modules\module.py:1553, in Module._wrapped_call_impl(self, *args, **kwargs)
#    1551     return self._compiled_call_impl(*args, **kwargs)  # type: ignore[misc]
#    1552 else:
# -> 1553     return self._call_impl(*args, **kwargs)
#
# File c:\Users\lab_aeroComp\anaconda3\envs\arvi-env\Lib\site-packages\torch\nn\modules\module.py:1562, in Module._call_impl(self, *args, **kwargs)
#    1557 # If we don't have any hooks, we want to skip the rest of the logic in
#    1558 # this function, and just call forward.
#    1559 if not (self._backward_hooks or self._backward_pre_hooks or self._forward_hooks or self._forward_pre_hooks
#    1560         or _global_backward_pre_hooks or _global_backward_hooks
#    1561         or _global_forward_hooks or _global_forward_pre_hooks):
# -> 1562     return forward_call(*args, **kwargs)
#    1564 try:
#    1565     result = None
#
# File c:\Users\lab_aeroComp\anaconda3\envs\arvi-env\Lib\site-packages\torch_geometric\nn\conv\cheb_conv.py:163, in ChebConv.forward(self, x, edge_index, edge_weight, batch, lambda_max)
#     161 Tx_0 = x
#     162 Tx_1 = x  # Dummy.
# --> 163 out = self.lins[0](Tx_0)
#     165 # propagate_type: (x: Tensor, norm: Tensor)
#     166 if len(self.lins) > 1:
#
# File c:\Users\lab_aeroComp\anaconda3\envs\arvi-env\Lib\site-packages\torch\nn\modules\module.py:1716, in Module.__getattr__(self, name)
#    1707         self._backward_pre_hooks = OrderedDict()
#    1709 # On the return type:
#    1710 # We choose to return `Any` in the `__getattr__` type signature instead of a more strict `Union[Tensor, Module]`.
#    1711 # This is done for better interop with various type checkers for the end users.
#    (...)   1714 # See full discussion on the problems with returning `Union` here
#    1715 # https://github.com/microsoft/pyright/issues/4213
# -> 1716 def __getattr__(self, name: str) -> Any:
#    1717     if '_parameters' in self.__dict__:
#    1718         _parameters = self.__dict__['_parameters']
#
# KeyboardInterrupt:

# %% [markdown]
# ### Training History

# %%
with open(f"artifacts/surface/{model_name}/{model_name}_history_{num_epochs}.pkl", 'rb') as f:
    # Load the history dictionary
    train_history = pickle.load(f)
    val_history = pickle.load(f)
    
train_total_loss = train_history['train_loss']
val_total_loss = val_history['val_loss']    

plt.figure(figsize=(10, 6))
plt.plot(train_total_loss, label='Train Total Loss', color='blue')
plt.plot(val_total_loss, label='Val Total Loss', color='green')
# plt.ylim(0.0001, 1)
plt.xlabel('Epoch')
plt.ylabel('Loss')
plt.title('Training History')
plt.legend()
plt.grid(True)
plt.yscale('log') 
plt.show()

# %% [markdown]
# ### Plot train loss history

# %%
train_total_loss = train_history['train_loss']
train_reconstruction_loss = train_history['reconstruction_loss']
train_map_loss = train_history['map_loss']

plt.figure(figsize=(10, 6))
plt.plot(train_total_loss, label='Train Total Loss', color='blue')
plt.plot(train_reconstruction_loss, label='Train Reconstruction Loss', color='green')
plt.plot(train_map_loss, label='Train Map Loss', color='red')
# plt.ylim(0.0001, 1)
plt.xlabel('Epoch')
plt.ylabel('Loss')
plt.title('Training History')
plt.legend()
plt.grid(True)
plt.yscale('log') 
plt.show()

# %% [markdown]
# ### Plot validation loss history

# %%
val_total_loss = val_history['val_loss']
val_reconstruction_loss = val_history['reconstruction_loss']
val_map_loss = val_history['map_loss']

plt.figure(figsize=(10, 6))
plt.plot(val_total_loss, label='Train Total Loss', color='blue')
plt.plot(val_reconstruction_loss, label='Train Reconstruction Loss', color='green')
plt.plot(val_map_loss, label='Train Map Loss', color='red')
plt.xlabel('Epoch')
plt.ylabel('Loss')
# plt.ylim(0.0001, 1)
# plt.ylim(0.001, 10)
plt.title('Validation History')
plt.legend()
plt.grid(True)
plt.yscale('log') 
plt.show()

# %% [markdown]
# ## Plot results

# %% [markdown]
# ### Matplotlib Plotting

# %%
with open(os.path.join(config['config']['split_dir'], 'scaler.pkl'), 'rb') as f:
    scaler = f.read()
    
plot = Plot(train_dataset=train_dataset, val_dataset=val_dataset, model=model)

# %%
from src.utils.metrics import mse_error, mae_error, rmse_error, relative_error
from src.training.test import test

error_func = [mse_error, mae_error, rmse_error, relative_error]
test_results, total_error, total_error_list = test(model = model, 
                                 test_loader = train_loader,
                                 device = device, 
                                 error_func = error_func)

total_error
# Out:
# {'total_mse_error': {0: 0.41818035194092856,
#   1: 0.08300778196392118,
#   2: 0.06543163578093976},
#  'total_mae_error': {0: 0.4706801062680944,
#   1: 0.19563223788664288,
#   2: 0.207407564047153},
#  'total_rmse_error': {0: 0.5154417862531042,
#   1: 0.2580517377078968,
#   2: 0.24234575084852475},
#  'total_relative_error': {0: 0.3008723109688637,
#   1: 0.07418614598908836,
#   2: 0.0884209617965576}}

# %%
# Create a single figure with two subplots side by side
fig = plt.figure(figsize=(20, 8))

# First subplot - Relative Error
params_list = np.array(list(total_error_list['total_relative_error'][0].keys())).reshape(-1, 2)
error_values = np.array(list(total_error_list['total_relative_error'][0].values()))*100

ax1 = fig.add_subplot(121, projection='3d')
# Create a surface plot instead of scatter
from scipy.interpolate import griddata
import numpy as np

# Create a regular grid for interpolation
xi = np.linspace(params_list[:, 0].min(), params_list[:, 0].max(), 50)
yi = np.linspace(params_list[:, 1].min(), params_list[:, 1].max(), 50)
xi_grid, yi_grid = np.meshgrid(xi, yi)

# Interpolate the error values onto the regular grid
zi_grid = griddata((params_list[:, 0], params_list[:, 1]), error_values, (xi_grid, yi_grid), method='cubic')

# Create the surface plot
surface1 = ax1.plot_surface(xi_grid, yi_grid, zi_grid, cmap='viridis', alpha=0.8)
ax1.set_xlabel('Re')
ax1.set_ylabel('AoA')
ax1.set_zlabel('Relative Error (%)')
ax1.set_zlim(0, 100)
ax1.set_title(f'Relative Error in Parameter Space\nMean: {total_error["total_relative_error"][0]*100:.2f}%')
plt.colorbar(surface1, ax=ax1)

# Second subplot - MSE Error
params_list = np.array(list(total_error_list['total_mse_error'][0].keys())).reshape(-1, 2)
error_values = np.array(list(total_error_list['total_mse_error'][0].values()))
ax2 = fig.add_subplot(122, projection='3d')
# Create a surface plot instead of scatter

# Create a regular grid for interpolation
xi = np.linspace(params_list[:, 0].min(), params_list[:, 0].max(), 50)
yi = np.linspace(params_list[:, 1].min(), params_list[:, 1].max(), 50)
xi_grid, yi_grid = np.meshgrid(xi, yi)

# Interpolate the error values onto the regular grid
zi_grid = griddata((params_list[:, 0], params_list[:, 1]), error_values, (xi_grid, yi_grid), method='cubic')

# Create the surface plot
surface2 = ax2.plot_surface(xi_grid, yi_grid, zi_grid, cmap='viridis', alpha=0.8)
ax2.set_xlabel('Re')
ax2.set_ylabel('AoA')
ax2.set_zlabel('MSE Error')
# ax2.set_zlim(0, 1)
ax2.set_title(f'MSE Error in Parameter Space\nMean: {total_error["total_mse_error"][0]:.3f}')
plt.suptitle('Pressure Coefficient (Cp)', y = 1.1, fontsize = 18)
plt.colorbar(surface2, ax=ax2)

plt.tight_layout()
plt.show()

# %% [markdown]
# Original

# %%
index = 14

test_plot_data = train_dataset[index].to(device)
test_param = test_plot_data.params

estimated_x, latent_variables, estimated_latent_variables = model(test_plot_data, test_param)
estimated_x = estimated_x.detach().cpu().numpy()

plt.figure(figsize=(10, 6))
plt.title(f"Parameters: Re = {test_param[0].item()}, AoA = {test_param[1].item()}")
plt.xlabel('X Position')
plt.ylabel('Cp Value')
plt.plot(test_plot_data.pos[:, 0].cpu().numpy(), estimated_x[:, 0], label='Estimated Cp', color='blue')
plt.plot(test_plot_data.pos[:, 0].cpu().numpy(), test_plot_data.y[:, 0].cpu().numpy(), label='Ground Truth Cp', color='red')
plt.show()

print(f"Cfx MSE: {torch.nn.functional.mse_loss(input=torch.tensor(estimated_x[:, 1]), target=torch.tensor(test_plot_data.y[:, 1].cpu().numpy()), reduction='mean')}")
plt.figure(figsize=(10, 6))
plt.title(f"Parameters: Re = {test_param[0].item()}, AoA = {test_param[1].item()}")
plt.xlabel('X Position')
plt.ylabel('Cfx Value')
plt.plot(test_plot_data.pos[:, 0].cpu().numpy(), estimated_x[:, 1], label='Estimated Cp', color='blue')
plt.plot(test_plot_data.pos[:, 0].cpu().numpy(), test_plot_data.y[:, 1].cpu().numpy(), label='Ground Truth Cp', color='red')
plt.show()

print(f"Cfy MSE: {torch.nn.functional.mse_loss(input=torch.tensor(estimated_x[:, 2]), target=torch.tensor(test_plot_data.y[:, 2].cpu().numpy()), reduction='mean')}")
plt.figure(figsize=(10, 6))
plt.title(f"Parameters: Re = {test_param[0].item()}, AoA = {test_param[1].item()}")
plt.xlabel('X Position')
plt.ylabel('Cfy Value')
plt.plot(test_plot_data.pos[:, 0].cpu().numpy(), estimated_x[:, 2], label='Estimated Cp', color='blue')
plt.plot(test_plot_data.pos[:, 0].cpu().numpy(), test_plot_data.y[:, 2].cpu().numpy(), label='Ground Truth Cp', color='red')
plt.show()

plt.close()
# Out:
# Cfx MSE: 0.5065664052963257
# Cfy MSE: 0.18246297538280487

# %% [markdown]
# # Evaluation metric
